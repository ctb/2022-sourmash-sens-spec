# %% [markdown]
# # Explore the concept of unicity groups

# %%
import pandas as pd

# %%
df = pd.read_csv('bork-summ.csv')

# %%
df
# Out:
#     count superkingdom           phylum          class                  order  \
# 0     190  d__Bacteria  p__Firmicutes_A  c__Clostridia  o__Christensenellales
# 1     197  d__Bacteria  p__Firmicutes_A  c__Clostridia  o__Christensenellales
# 2     197  d__Bacteria  p__Firmicutes_A  c__Clostridia  o__Christensenellales
# 3     197  d__Bacteria  p__Firmicutes_A  c__Clostridia  o__Christensenellales
# 4     197  d__Bacteria  p__Firmicutes_A  c__Clostridia                    NaN
# 5     197  d__Bacteria  p__Firmicutes_A            NaN                    NaN
# 6     197  d__Bacteria              NaN            NaN                    NaN
# 7     137  d__Bacteria  p__Firmicutes_A  c__Clostridia  o__Christensenellales
# 8     142  d__Bacteria  p__Firmicutes_A  c__Clostridia  o__Christensenellales
# 9     142  d__Bacteria  p__Firmicutes_A  c__Clostridia  o__Christensenellales
# 10    142  d__Bacteria  p__Firmicutes_A  c__Clostridia  o__Christensenellales
# ...

# %%
staph_inf_df = pd.read_csv('staph_inf.summ.csv')
staph_inf_df['percent'] = round(staph_inf_df['count'] / staph_inf_df['total_counts'] * 100, 1)
staph_inf_df[['count', 'total_counts', 'percent', 'superkingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species']]
# Out:
#    count  total_counts  percent superkingdom         phylum       class  \
# 0   1480        2369.0     62.5  d__Bacteria  p__Firmicutes  c__Bacilli
# 1   1815        2369.0     76.6  d__Bacteria  p__Firmicutes  c__Bacilli
# 2   1861        2369.0     78.6  d__Bacteria  p__Firmicutes  c__Bacilli
# 3   1867        2369.0     78.8  d__Bacteria  p__Firmicutes  c__Bacilli
# 4   1944        2369.0     82.1  d__Bacteria  p__Firmicutes  c__Bacilli
# 5   1944        2369.0     82.1  d__Bacteria  p__Firmicutes         NaN
# 6   2363        2369.0     99.7  d__Bacteria            NaN         NaN
# 7      6        2369.0      0.3          NaN            NaN         NaN
#
#                  order                family              genus  \
# 0  o__Staphylococcales  f__Staphylococcaceae  g__Staphylococcus
# 1  o__Staphylococcales  f__Staphylococcaceae  g__Staphylococcus
# 2  o__Staphylococcales  f__Staphylococcaceae                NaN
# ...

# %%
print(staph_inf_df[['count', 'total_counts', 'percent', 'superkingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species']].to_markdown())
# Out:
# |    |   count |   total_counts |   percent | superkingdom   | phylum        | class      | order               | family               | genus             | species                  |
# |---:|--------:|---------------:|----------:|:---------------|:--------------|:-----------|:--------------------|:---------------------|:------------------|:-------------------------|
# |  0 |    1480 |           2369 |      62.5 | d__Bacteria    | p__Firmicutes | c__Bacilli | o__Staphylococcales | f__Staphylococcaceae | g__Staphylococcus | s__Staphylococcus aureus |
# |  1 |    1815 |           2369 |      76.6 | d__Bacteria    | p__Firmicutes | c__Bacilli | o__Staphylococcales | f__Staphylococcaceae | g__Staphylococcus | nan                      |
# |  2 |    1861 |           2369 |      78.6 | d__Bacteria    | p__Firmicutes | c__Bacilli | o__Staphylococcales | f__Staphylococcaceae | nan               | nan                      |
# ...

# %%
bork_df = pd.read_csv('bork_inf.summ.csv')
bork_df
# Out:
#    count superkingdom           phylum          class                  order  \
# 0    137  d__Bacteria  p__Firmicutes_A  c__Clostridia  o__Christensenellales
# 1    142  d__Bacteria  p__Firmicutes_A  c__Clostridia  o__Christensenellales
# 2    144  d__Bacteria  p__Firmicutes_A  c__Clostridia  o__Christensenellales
# 3    145  d__Bacteria  p__Firmicutes_A  c__Clostridia  o__Christensenellales
# 4    147  d__Bacteria  p__Firmicutes_A  c__Clostridia                    NaN
# 5    147  d__Bacteria  p__Firmicutes_A            NaN                    NaN
# 6    147  d__Bacteria              NaN            NaN                    NaN
#
#               family          genus                       species  strain  \
# 0  f__Borkfalkiaceae  g__Borkfalkia  s__Borkfalkia excrementavium     NaN
# 1  f__Borkfalkiaceae  g__Borkfalkia                           NaN     NaN
# 2  f__Borkfalkiaceae            NaN                           NaN     NaN
# ...

# %%
bork_df['percent'] = round(bork_df['count'] / bork_df['total_counts'] * 100, 1)

bork_df[['count', 'total_counts', 'percent', 'superkingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species']]
# Out:
#    count  total_counts  percent superkingdom           phylum          class  \
# 0    137         147.0     93.2  d__Bacteria  p__Firmicutes_A  c__Clostridia
# 1    142         147.0     96.6  d__Bacteria  p__Firmicutes_A  c__Clostridia
# 2    144         147.0     98.0  d__Bacteria  p__Firmicutes_A  c__Clostridia
# 3    145         147.0     98.6  d__Bacteria  p__Firmicutes_A  c__Clostridia
# 4    147         147.0    100.0  d__Bacteria  p__Firmicutes_A  c__Clostridia
# 5    147         147.0    100.0  d__Bacteria  p__Firmicutes_A            NaN
# 6    147         147.0    100.0  d__Bacteria              NaN            NaN
#
#                    order             family          genus  \
# 0  o__Christensenellales  f__Borkfalkiaceae  g__Borkfalkia
# 1  o__Christensenellales  f__Borkfalkiaceae  g__Borkfalkia
# 2  o__Christensenellales  f__Borkfalkiaceae            NaN
# 3  o__Christensenellales                NaN            NaN
# ...

# %%
print(bork_df[['count', 'total_counts', 'percent', 'superkingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species']].to_markdown())
# Out:
# |    |   count |   total_counts |   percent | superkingdom   | phylum          | class         | order                 | family            | genus         | species                      |
# |---:|--------:|---------------:|----------:|:---------------|:----------------|:--------------|:----------------------|:------------------|:--------------|:-----------------------------|
# |  0 |     137 |            147 |      93.2 | d__Bacteria    | p__Firmicutes_A | c__Clostridia | o__Christensenellales | f__Borkfalkiaceae | g__Borkfalkia | s__Borkfalkia excrementavium |
# |  1 |     142 |            147 |      96.6 | d__Bacteria    | p__Firmicutes_A | c__Clostridia | o__Christensenellales | f__Borkfalkiaceae | g__Borkfalkia | nan                          |
# |  2 |     144 |            147 |      98   | d__Bacteria    | p__Firmicutes_A | c__Clostridia | o__Christensenellales | f__Borkfalkiaceae | nan           | nan                          |
# ...
